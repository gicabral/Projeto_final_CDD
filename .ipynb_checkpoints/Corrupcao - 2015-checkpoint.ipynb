# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corrup = pd.read_excel('corruption_perception.xlsx')

# %%
corrup.tail(5)
# Out:
#            geo  2012  2013  2014  2015  2016  2017
# 172  Venezuela    19    20    19    17    17    18
# 173    Vietnam    31    31    31    31    33    35
# 174      Yemen    23    18    19    18    14    16
# 175     Zambia    37    38    38    38    38    37
# 176   Zimbabwe    20    21    21    21    22    22

# %%
corrup = corrup.loc[:, ['geo', 2015]]
corrup = corrup.rename(columns = {'geo': "Países", 2015:'Corrupção 2015'})

corrup_nam=corrup.dropna()

corrup_idx=corrup_nam.set_index("Países")
corrup_idx
# Out:
#                                 Corrupção 2015
# Países
# Afghanistan                                 11
# Albania                                     36
# Algeria                                     36
# Angola                                      15
# Argentina                                   32
# Armenia                                     35
# Australia                                   79
# Austria                                     76
# Azerbaijan                                  29
# Bahamas                                      0
# Bahrain                                     51
# Bangladesh                                  25
# Barbados                                     0
# Belarus                                     32
# Belgium                                     77
# Benin                                       37
# Bhutan                                      65
# Bolivia                                     34
# Bosnia and Herzegovina                      38
# ...

# %%
corrup_idx.to_excel('corrup_limpo.xlsx')
