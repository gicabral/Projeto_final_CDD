# %%
import pandas as pd
import seaborn as sns
import sys
import matplotlib.pyplot as plt
import numpy as np

# %%
dados_expectativa = pd.read_excel('expecativa.xlsx')

dados_expectativa.dropna()


dados_expectativa
# Out:
#               Life expectancy   1800   1801   1802   1803   1804   1805  \
# 0                    Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN
# 1                 Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16
# 2       Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN
# 3                     Albania  35.40  35.40  35.40  35.40  35.40  35.40
# 4                     Algeria  28.82  28.82  28.82  28.82  28.82  28.82
# 5              American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 6                     Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 7                      Angola  26.98  26.98  26.98  26.98  26.98  26.98
# 8                    Anguilla    NaN    NaN    NaN    NaN    NaN    NaN
# 9         Antigua and Barbuda  33.54  33.54  33.54  33.54  33.54  33.54
# 10                  Argentina  33.20  33.20  33.20  33.20  33.20  33.20
# 11                    Armenia  34.00  34.00  34.00  34.00  34.00  34.00
# ...

# %%
df= dados_expectativa.loc[:,]

exp_idx = df.set_index('Life expectancy')

exp_idx
# Out:
#                            1800   1801   1802   1803   1804   1805   1806  \
# Life expectancy
# Abkhazia                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan               28.21  28.20  28.19  28.18  28.17  28.16  28.15
# Akrotiri and Dhekelia       NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                   35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                   28.82  28.82  28.82  28.82  28.82  28.82  28.82
# American Samoa              NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra                     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Angola                    26.98  26.98  26.98  26.98  26.98  26.98  26.98
# Anguilla                    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Antigua and Barbuda       33.54  33.54  33.54  33.54  33.54  33.54  33.54
# Argentina                 33.20  33.20  33.20  33.20  33.20  33.20  33.20
# ...

# %%
exp_idx_15 = exp_idx.loc[:,('2015')]

exp_idx_15
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [2015] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f6670d76297b> in <module>()
# ----> 1 exp_idx_15 = exp_idx.loc[:,('2015')]
#       2
#       3 exp_idx_15
#
# ...
