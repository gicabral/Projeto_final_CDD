# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corrup = pd.read_excel('corrupção.xls')

# %%
corrup.tail(5)
# Out:
#      Country Name Country Code  \
# 259        Kosovo          XKX
# 260   Yemen, Rep.          YEM
# 261  South Africa          ZAF
# 262        Zambia          ZMB
# 263      Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  1960  \
# 259  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 260  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 261  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 262  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
# 263  CPIA transparency, accountability, and corrupt...  IQ.CPA.TRAN.XQ   NaN
#
#      1961  1962  1963  1964  1965  ...   2008  2009  2010  2011  2012  2013  \
# 259   NaN   NaN   NaN   NaN   NaN  ...    NaN   3.0   3.0   3.0   3.0   3.0
# 260   NaN   NaN   NaN   NaN   NaN  ...    3.0   3.0   2.5   2.5   2.0   2.0
# 261   NaN   NaN   NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
corrup = corrup.loc[:, ['Country Name', "2015"]]
corrup = corrup.rename(columns = {2015:'Corrupção em 2015'})

corrup_nam=corrup.dropna()

corrup_idx=corrup_nam.set_index("Country Name")
corrup_idx
# Out:
#                                                         2015
# Country Name
# Afghanistan                                         2.000000
# Arab World                                          2.200000
# Burundi                                             2.000000
# Benin                                               3.500000
# Burkina Faso                                        3.500000
# Bangladesh                                          2.500000
# Bolivia                                             3.000000
# Bhutan                                              4.500000
# Central African Republic                            2.500000
# Cote d'Ivoire                                       3.000000
# Cameroon                                            2.500000
# Congo, Dem. Rep.                                    2.000000
# Congo, Rep.                                         2.000000
# Comoros                                             2.500000
# ...

# %%
corrup_idx.to_excel('corrup_limpo.xlsx')
